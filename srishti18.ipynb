# %% [markdown]
# <a href="https://colab.research.google.com/github/Srishtik-ui/Srishti/blob/main/srishti18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
ipl=pd.read_csv('/content/matches.csv')

# %%
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
ipl.shape
# Out:
# (1095, 20)

# %%
ipl['player_of_match'].value_counts()
# Out:
# player_of_match
# AB de Villiers       25
# CH Gayle             22
# RG Sharma            19
# DA Warner            18
# V Kohli              18
#                      ..
# NV Ojha               1
# KV Sharma             1
# Washington Sundar     1
# PD Collingwood        1
# Shahbaz Ahmed         1
# Name: count, Length: 291, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:5]
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# Name: count, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:10]
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# Name: count, dtype: int64

# %%
list(ipl['player_of_match'].value_counts()[0:5].keys())
# Out:
# ['AB de Villiers', 'CH Gayle', 'RG Sharma', 'DA Warner', 'V Kohli']

# %%
plt.figure(figsize=(8,5))
plt.bar(list(ipl['player_of_match'].value_counts()[0:10].keys()),list(ipl['player_of_match'].value_counts()[0:10]),color=["blue","purple","red"])
plt.show()

# %%
ipl['result'].value_counts()
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
ipl['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 143
# Kolkata Knight Riders          122
# Chennai Super Kings            122
# Rajasthan Royals               120
# Royal Challengers Bangalore    113
# Sunrisers Hyderabad             88
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Delhi Capitals                  50
# Deccan Chargers                 43
# Punjab Kings                    24
# Gujarat Titans                  22
# Pune Warriors                   20
# Lucknow Super Giants            19
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Royal Challengers Bengaluru      8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
list(ipl['toss_winner'].value_counts()[0:10].keys())
# Out:
# ['Mumbai Indians',
#  'Kolkata Knight Riders',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad',
#  'Kings XI Punjab',
#  'Delhi Daredevils',
#  'Delhi Capitals',
#  'Deccan Chargers']

# %%
plt.figure(figsize=(10,7))
plt.hist(ipl['toss_winner'])
plt.title("toss_winner")
plt.xlabel("toss_winner")
plt.ylabel("count")
plt.show()

# %%
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
ipl['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.pie(ipl['winner'].value_counts(),labels=list(ipl['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
 ipl['city'].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Mohali              5
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Guwahati            3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
plt.pie(ipl['city'].value_counts(),labels=list(ipl['city'].value_counts().keys()),autopct='%0.1f%%',radius=3)
plt.pie([1],colors=['w'],radius=1)
plt.show()

# %%
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
ipl['season'].value_counts()
# Out:
# season
# 2013       76
# 2023       74
# 2012       74
# 2022       74
# 2011       73
# 2024       71
# 2018       60
# 2021       60
# 2020/21    60
# 2019       60
# 2016       60
# 2014       60
# 2009/10    60
# 2017       59
# 2015       59
# 2007/08    58
# 2009       57
# Name: count, dtype: int64

# %%
ipl['season'].value_counts()[0:10].keys()
# Out:
# Index(['2013', '2023', '2012', '2022', '2011', '2024', '2018', '2021',
#        '2020/21', '2019'],
#       dtype='object', name='season')

# %%
list(ipl['season'].value_counts().keys())
# Out:
# ['2013',
#  '2023',
#  '2012',
#  '2022',
#  '2011',
#  '2024',
#  '2018',
#  '2021',
#  '2020/21',
#  '2019',
#  '2016',
#  '2014',
#  '2009/10',
#  '2017',
#  '2015',
#  '2007/08',
#  '2009']

# %%
plt.figure(figsize=(5,5))
plt.bar(list(ipl['season'].value_counts()[0:5].keys()),list(ipl['season'].value_counts()[0:5]),color=["yellow","blue","red","green"])
plt.show()

# %%
ipl['result']
# Out:
# 0          runs
# 1          runs
# 2       wickets
# 3       wickets
# 4       wickets
#          ...
# 1090    wickets
# 1091    wickets
# 1092    wickets
# 1093       runs
# 1094    wickets
# Name: result, Length: 1095, dtype: object

# %%
ipl['result'].value_counts()
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
list(ipl['result'].value_counts().keys())
# Out:
# ['wickets', 'runs', 'tie', 'no result']

# %%
plt.figure(figsize=(5,5))
plt.hist(ipl['result'],color="purple")
plt.title("result")
plt.xlabel("result")
plt.ylabel("matches")
plt.show()

# %%
ipl['player_of_match']
# Out:
# 0           BB McCullum
# 1            MEK Hussey
# 2           MF Maharoof
# 3            MV Boucher
# 4             DJ Hussey
#              ...
# 1090    Abhishek Sharma
# 1091           MA Starc
# 1092           R Ashwin
# 1093      Shahbaz Ahmed
# 1094           MA Starc
# Name: player_of_match, Length: 1095, dtype: object

# %%
ipl['player_of_match'].value_counts()[0:10]
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# Name: count, dtype: int64

# %%
list(ipl['player_of_match'].value_counts()[0:10].keys())
# Out:
# ['AB de Villiers',
#  'CH Gayle',
#  'RG Sharma',
#  'DA Warner',
#  'V Kohli',
#  'MS Dhoni',
#  'SR Watson',
#  'YK Pathan',
#  'RA Jadeja',
#  'AD Russell']

# %%
plt.figure(figsize=(5,5))
plt.pie(ipl['player_of_match'].value_counts()[0:10],labels=list(ipl['player_of_match'].value_counts()[0:10].keys()),autopct='%0.1f%%')
plt.show()

# %%
ipl['super_over']
# Out:
# 0       N
# 1       N
# 2       N
# 3       N
# 4       N
#        ..
# 1090    N
# 1091    N
# 1092    N
# 1093    N
# 1094    N
# Name: super_over, Length: 1095, dtype: object

# %%
ipl['super_over'].value_counts()[0:10]
# Out:
# super_over
# N    1081
# Y      14
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,7))
plt.bar(list(ipl['super_over'].value_counts()[0:10].keys()),list(ipl['super_over'].value_counts()[0:10]),color=["yellow","blue"])
plt.title("super over")
plt.xlabel("super over")
plt.ylabel("matches")
plt.show()

# %%
ipl['id'].value_counts()[0:10]
# Out:
# id
# 335982     1
# 1178408    1
# 1178414    1
# 1178413    1
# 1178412    1
# 1178411    1
# 1178410    1
# 1178409    1
# 1178407    1
# 1136610    1
# Name: count, dtype: int64

# %%
list(ipl['id'].value_counts()[0:10].keys())
# Out:
# [335982,
#  1178408,
#  1178414,
#  1178413,
#  1178412,
#  1178411,
#  1178410,
#  1178409,
#  1178407,
#  1136610]
